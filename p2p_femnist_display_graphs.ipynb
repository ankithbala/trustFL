# %%
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score  
import numpy as np
import torch

# %%
epoch_total = 500
num_nodes = 5
pickle_name = "femnist-p2p-epoch-"+str(epoch_total)

# %%
import pickle

try:
    my_pickle_results = pickle.load( open( pickle_name+'.pickle', "rb" ) )
    result = {}
    result2 = {}
    myResults = my_pickle_results
except (OSError, IOError) as e:
    my_pickle_results = {}
    result = {}
    result2 = {}

# %%
train_accuracies = my_pickle_results["p2p"]["train_accuracies"]
train_losses = my_pickle_results["p2p"]["train_losses"]
test_accuracies = my_pickle_results["p2p"]["test_accuracies"]
test_losses = my_pickle_results["p2p"]["test_losses"]
f1_scores = my_pickle_results["p2p"]["f1_scores"]
time_taken = my_pickle_results["p2p"]["time_taken"]
all_y_pred = my_pickle_results["p2p"]["ypred_test"]
all_ylabels = y_pred = my_pickle_results["p2p"]["ylabels_test"]
f1_score_prime =  my_pickle_results["p2p"]["f1_global"]

# %%
# print(time_taken)
# y_pred_global = torch.cat(all_y_pred)
# y_true_label_global = torch.cat(all_ylabels)
# print(f1_scores[-1])
# print()
# print("Global f1_Score")
# #f1_score(y_true_label_global.cpu(), torch.argmax(y_pred_global, dim=-1).cpu(), average="weighted")
# global_f1_score = f1_score(y_true_label_global.cpu(), y_pred_global.cpu(), average="weighted")
# print(global_f1_score)

# %%
print(time_taken)
print(f1_score_prime)
# Out:
# 42.04379177093506
# 0.5936291951576805

# %%
print(sum(train_accuracies[-1])/num_nodes)
plt.plot(train_accuracies)
plt.xlabel("Epochs")
plt.ylabel("Training Accuracy")
#plt.show()
plt.savefig("results/femnist/epoch_500/p2p/training_accuracy.png")
# Out:
# 0.8763248969053677

# %%
print(sum(train_losses[-1])/num_nodes)
plt.plot(train_losses)
plt.xlabel("Epochs")
plt.ylabel("Training Loss")
#plt.show()
plt.savefig("results/femnist/epoch_500/p2p/training_loss.png")
# Out:
# 0.579308629532655

# %%
print(sum(test_accuracies[-1])/num_nodes)
plt.plot(test_accuracies)
plt.xlabel("Epochs")
plt.ylabel("Testing Accuracy")
#plt.show()
plt.savefig("results/femnist/epoch_500/p2p/testing_accuracy.png")
# Out:
# 0.5842857142857143

# %%
print(sum(test_losses[-1])/num_nodes)
plt.plot(test_losses)
plt.xlabel("Epochs")
plt.ylabel("Testing Loss")
#plt.show()
plt.savefig("results/femnist/epoch_500/p2p/testing_loss.png")
# Out:
# 4.273796534538269
